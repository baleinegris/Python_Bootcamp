# %% [markdown]
# # Day 1 Exercises
# ## Data Types

# %% [markdown]
# #### 1. What types are involved in the following expressions? What data type will each expression evaluate to?

# %%
8 * 2.5
# Out:
# 20.0

# %% [markdown]
# This uses an int and a float, and evaluates to a float

# %%
9 / 2
# Out:
# 4.5

# %% [markdown]
# This uses two ints, and evaluates to a float

# %%
1.5 * 2 >= 7 - 3
# Out:
# False

# %% [markdown]
# This uses floats and integers, and evaluates to a boolean

# %% [markdown]
# #### 2. In which order will the expressions be evaluated?

# %%
6 * 3 + 7 * 4
# Out:
# 46

# %% [markdown]
# This will evaluate (6\*3), then (7\*4), then the +

# %%
5 - 2 * 3 ** 4
# Out:
# -157

# %% [markdown]
# This will evaluate 3\*\*4, then the \*, then then -

# %%
(5 - 2) * 3 ** 4
# Out:
# 243

# %% [markdown]
# This will evaluate the - in parentheses, then the \*\*, then the \*

# %%
5 + 2 >= 3 * 4
# Out:
# False

# %% [markdown]
# This will evaluate the \*, then the +, then the >=

# %% [markdown]
# ## Comments and Errors

# %% [markdown]
# #### 1. Which of these expressions results in an error? Why does each error occur?

# %%
((((5 * 4 ** 7))))
# Out:
# 81920

# %% [markdown]
# No error

# %%
84 *= 0.5 / 7
# Out:
#   Cell In[9], line 1
#     84 *= 0.5 / 7
#     ^
# SyntaxError: 'literal' is an illegal expression for augmented assignment

# %% [markdown]
# This throws an error because we can't start variable names with numbers

# %%
(-(-(-(-5 * (4 + 3)))))
# Out:
# 35

# %% [markdown]
# No error

# %%
5 * 3 = weight
# Out:
#   Cell In[11], line 1
#     5 * 3 = weight
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %% [markdown]
# This throws an error because we put the variable name on the left when assigning

# %%
73 / -----------5
# Out:
# -14.6

# %% [markdown]
# No error, just lots of redundant - signs

# %% [markdown]
# #### 2. Write a block of code to check if the value is a string. If it is, print out a message saying it is valid. Otherwise, raise an exception with a message saying the value must be a string.

# %%
value = 6

# Your code goes here

if type(value) == str:
    print("valid")
else:
    raise Exception("value must be a string")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[13], line 8
#       4
#       5 if type(value) == str:
#       6     print("valid")
#       7 else:
# ----> 8     raise Exception("value must be a string")
#
# Exception: value must be a string

# %% [markdown]
# #### 3. What are the following errors?

# %%
arr = [1, 2, 3]
print(arr[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 2
#       1 arr = [1, 2, 3]
# ----> 2 print(arr[3])
#
# IndexError: list index out of range

# %% [markdown]
# We are getting an index error because we are indexing the 3rd index of a list with only 3 elements (indexed from 0)

# %%
fullName = "Taylor Swift"
print(full_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 fullName = "Taylor Swift"
# ----> 2 print(full_name)
#
# NameError: name 'full_name' is not defined

# %% [markdown]
# We get a name error here because full_name isn't the same as fullName and so isn't defined

# %%
2 + '2' + 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 2 + '2' + 4
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# Here we are mixing multiple data types (strings and ints) in an addition, which isn't valid, so we get a type error

# %% [markdown]
# ## Functions

# %% [markdown]
# #### 1. Following the function design recipe, define a function that converts kilometers into miles. (Assume there are 1.6 kilometers in a mile.)

# %%
# Your code goes here

def kil_to_miles(kilometers):
    """
    Convert kilometers to miles, 
    assuming 1.6 kilometers is equal to 1 mile.
    """
    miles = kilometers / 1.6
    return miles

# %% [markdown]
# #### 2. What value is printed in the below code?

# %%
answer = 3

def answer_to_everything():
    '''Return the answer to life, the universe, and everything'''
    answer = 42
    return answer

answer_to_everything()

print(answer)
# Out:
# 3

# %% [markdown]
# This returns 3, because we changed the value of the local version of answer in the scope of the function, which doesn't change the value of answer outside of the function

# %% [markdown]
# #### 3. Complete the body of the function. You can assume num is always >= 0.

# %%
def repeat(string, num):
    ''' Return string repeated num times.
    >>> repeat('yes', 4)
    'yesyesyesyes'
    >>> repeat('no', 0)
    ''
    >>> repeat('yesnomaybe', 3)
    'yesnomaybeyesnomaybeyesnomaybe'
    '''
    output = string * num

    return output

# %% [markdown]
# #### 4. Complete the function below. You can assume that number will always be a string with 10 digits and that the first 3 digits will always be the area code.

# %%
def is_416_number(number):
    ''' Check whether the number has a 416 area code.
    >>> is_416_number('(416)-555-5555')
    True
    >>> is_416_number('514 416 5555')
    False
    >>> is_416_number('4165554160')
    True
    '''
    # Your code goes here
    # Hint: replace () and spaces with nothing
    number = number.replace('(', '').replace(')', '').replace(' ', '')
    area_code = number[:3]
    return area_code == '416'
